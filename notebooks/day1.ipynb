# %%
# %conda install pymongo pandas 
# %pip install flatten_json
import pandas as pd
import pymongo
from flatten_json import flatten
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 14.6 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached flatten_json-0.1.13-py3-none-any.whl
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 13.9 MB/s eta 0:00:0000:0100:01
# ...
#   Using cached pytz-2022.2.1-py2.py3-none-any.whl (500 kB)
# ...

# %%
mongo_client = pymongo.MongoClient("mongodb://localhost:27017/")
mongo_database = mongo_client["tft_data"]
mongo_container = mongo_database["challenger"]
all_data = list(mongo_container.find().limit(2))

# %%
all_data
# Out:
# [{'_id': 'EUW1_6084000195',
#   'metadata': {'data_version': '5',
#    'match_id': 'EUW1_6084000195',
#    'participants': ['4vDKWDyLDh_efpYuChux5T41mLWrC5F5c-HQlmUDIqLXA4IbQ7RuFC8nhblzuqHgS7oVnom80uGyTg',
#     'D0QuHbLzIsV0WwhrmsvRxZtqCdCiexXWD3UQpqmO4XAE5G-UyBMMhICctijd1y9w1Rg-3aJmqonURA',
#     '_6YHT8kAvPPIUhjTgUQdPVBKLHZhBEJUx2Oa47UPCFQX8UQWGDKr4ivJ1FBinBALFsD0QTsVifWnEw',
#     'Rv0bOzEeDk1Afavn2a0nuFXhrhh2cEdWXxOw-cQyxGrk84AXiNuajeOCoBEUicrb_5aHGW8kWXWMgA',
#     'Az2i--gJndrpNpmwubU6nMFi54cAGFlmRG085xfF-Ehx6XeWsp8Q3Ps8eyNOI4fqZUyO_5k1SXZVcA',
#     'hKGEcQd_YaXnO6_NRyVb6Ss8gZZcmCPf_t8CC3kQd3NSi8xU7qJ1H5oT0F5YKtBB8GXQQhHuQbXCqw',
#     'DM_QmfxK1IxDnqUQ3vw3HQzoP7kE3PrNh740pDU5PUOp9I1-_CeyjcYfjm55lMaqf_LzJ5llrj2zLA',
#     'wvD3z7vny8qK6WuUxi7e7rl1c0zM9pFbozaTIlARXXYRkFnLe120sZxvB3_kRUxtg35NorzjOgWRIA']},
#   'info': {'game_datetime': 1664391678958,
#    'game_length': 2341.26904296875,
# ...

# %%
# result = json_normalize(data, 'counties', ['state', 'shortname', ['info', 'governor']])
df = pd.json_normalize(all_data, ["info", "participants"], "info")
#result = pd.json_normalize(result["augments"])

#result = pd.json_normalize(all_data, ["info", "participants", "augments"])
#result
df = result.explode('augments')

df
# Out:
#                                     augments  gold_left  last_round  level  \
# 0                   TFT6_Augment_SecondWind1          0          35      8
# 0              TFT6_Augment_ThrillOfTheHunt2          0          35      8
# 0                     TFT6_Augment_Ascension          0          35      8
# 1                   TFT6_Augment_FirstAidKit          0          35      8
# 1                   TFT7_Augment_LagoonOasis          0          35      8
# 1              TFT6_Augment_CyberneticShell2          0          35      8
# 2                TFT7_Augment_BandOfThieves1         18          38      8
# 2                 TFT6_Augment_TomeOfTraits1         18          38      8
# 2            TFT7_Augment_DragonmancerEmblem         18          38      8
# 3                     TFT7_Augment_MageTrait          0          38      8
# 3                 TFT6_Augment_TomeOfTraits1          0          38      8
# ...
